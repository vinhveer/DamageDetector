# %% [markdown]
# # MCP Jupyter smoke test
#
# Notebook này kiểm tra virtualenv `DamageDetector/.venv` có thể import `mcp_jupyter` và chạy code Python.

# %%
import sys
import mcp_jupyter

print(sys.executable)
print(mcp_jupyter.__name__)
# Out:
# /Users/nguyenquangvinh/Desktop/Lab/DamageDetector/.venv/bin/python
# mcp_jupyter

# %%
total = sum(range(1, 6))
print(f'total={total}')
assert total == 15
# Out:
# total=15
